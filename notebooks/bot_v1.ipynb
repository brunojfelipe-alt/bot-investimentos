# %%
# ============================================================

# PROJETO: BOT DE ANÁLISE DO MERCADO DE AÇÕES BRASILEIRO

# Autor: Bruno Januário Felipe

# Curso: Matemática Aplicada a Negócios

# Universidade: USP Ribeirão Preto

#

# Objetivo do projeto:

# Desenvolver um sistema automatizado capaz de coletar dados

# do mercado financeiro brasileiro, analisar ações utilizando

# indicadores técnicos e informações de notícias financeiras,

# gerar scores de investimento e avaliar estratégias através

# de backtesting.

#

# O projeto está dividido em versões progressivas (V1 -> V9),

# onde cada versão adiciona novas capacidades analíticas.

# ============================================================

# ============================================================

# V1 — COLETA E VISUALIZAÇÃO DE DADOS

# ============================================================

#

# Objetivo:

# Construir a base do sistema coletando dados históricos de

# ações brasileiras e exibindo informações básicas.

#

# Funcionalidades:

#

# - Baixar dados históricos de ações (ex: PETR4, VALE3)

# - Mostrar preço atual

# - Mostrar variação percentual diária

# - Plotar gráfico de preço ao longo do tempo

# - Criar Modos de Visualização: 
#   1 — Ranking de ações
#   2 — Análise de uma ação
#   3 — Backtest
#   4 — Portfólio do usuário
#   5 — Alertas
#   6 — Notícias

# Conceitos:


# PREÇO ATUAL

# Último preço negociado da ação.

#

# VARIAÇÃO PERCENTUAL

# Mede quanto o preço mudou em relação ao dia anterior.

#

# Fórmula:

#

# variação = (preço_atual - preço_anterior) / preço_anterior

#

# RETORNO PERCENTUAL

# Mede o ganho ou perda em determinado período.

#

# retorno = (preço_final - preço_inicial) / preço_inicial

#

# RETORNO ACUMULADO

# Mede o retorno total ao longo de vários períodos.

#

# Exemplo:

# Se uma ação subiu:

# 5% em janeiro

# 3% em fevereiro

# 2% em março

#

# O retorno acumulado é a combinação desses retornos.

#

# Bibliotecas típicas usadas:

# pandas, yfinance, matplotlib

# ============================================================

# V1.5 — ESTRUTURA DE BANCO DE DADOS

# ============================================================

#

# Objetivo:

# Criar um banco de dados local para armazenar informações

# coletadas pelo sistema.

#

# Dados armazenados:

#

# - preços históricos

# - volume de negociação

# - indicadores técnicos

# - scores gerados pelo sistema

# - notícias financeiras

#

# Vantagens:

#

# - evitar baixar os dados toda vez

# - permitir análises históricas

# - acelerar processamento

#

# Tecnologias possíveis:

#

# SQLite

# CSV

# Parquet

#

# Ideal para projetos iniciais: SQLite ou Parquet

# ============================================================

# V2 — RANKING DE DESEMPENHO

# ============================================================

#

# Objetivo:

# Comparar o desempenho das ações e criar rankings.

#

# Funcionalidades:

#

# - ranking das ações que mais subiram

# - ranking das ações que mais caíram

# - ranking por período:

# - diário

# - semanal

# - mensal

#

# Exemplo:

#

# Top ganhos do dia

#

# 1. WEGE3 +4.2%

# 2. PETR4 +3.1%

# 3. VALE3 +2.7%

#

# Isso ajuda a identificar:

#

# - ações em tendência

# - movimentos fortes do mercado

# ============================================================

# V3 — INDICADORES TÉCNICOS

# ============================================================

#

# Objetivo:

# Adicionar métricas matemáticas usadas em análise técnica.

#

# Indicadores implementados:

#

# MÉDIA MÓVEL (Moving Average)

#

# Média do preço em um número de dias.

#

# Exemplo:

# Média móvel de 20 dias (MM20)

#

# Ajuda a identificar tendência do mercado.

#

# Se preço > média móvel:

# tendência de alta

#

# Se preço < média móvel:

# tendência de baixa

#

#

# VOLUME

#

# Quantidade de ações negociadas em determinado período.

#

# Volume alto pode indicar:

#

# - grande interesse do mercado

# - possíveis movimentos fortes

#

#

# VOLATILIDADE

#

# Mede o quanto o preço oscila ao longo do tempo.

#

# Geralmente calculada usando:

#

# desvio padrão dos retornos

#

# Alta volatilidade:

# mercado instável

#

# Baixa volatilidade:

# mercado mais estável

#

#

# RSI (Relative Strength Index)

#

# Indicador de momentum que mede velocidade das variações

# de preço.

#

# Escala:

#

# 0 → 100

#

# RSI > 70

# ação sobrecomprada (pode cair)

#

# RSI < 30

# ação sobrevendida (pode subir)

#

#

# MACD (Moving Average Convergence Divergence)

#

# Indicador que mede relação entre duas médias móveis.

#

# Usado para detectar:

#

# - mudanças de tendência

# - força do movimento

#

# O MACD analisa a diferença entre:

#

# média móvel curta

# média móvel longa

#

# Quando o MACD cruza sua linha de sinal,

# pode indicar compra ou venda.

# ============================================================

# V3.5 — CORRELAÇÃO ENTRE AÇÕES

# ============================================================

#

# Objetivo:

# Medir relação entre os movimentos de diferentes ações.

#

# Correlação varia entre:

#

# -1  → movimento oposto

# 0  → sem relação

# +1  → movimento igual

#

# Exemplo:

#

# ITUB4 e BBDC4

# geralmente possuem alta correlação

#

# Isso ajuda em:

#

# - diversificação

# - construção de portfólio

# ============================================================

# V4 — SISTEMA DE ALERTAS

# ============================================================

#

# Objetivo:

# Detectar eventos importantes automaticamente.

#

# Exemplos de alertas:

#

# - ação subiu mais de 5%

# - ação caiu mais de 5%

# - volume anormal

# - cruzamento de médias móveis

#

# Inicialmente os alertas podem aparecer:

#

# - no terminal

# - em logs

#

# Futuro:

#

# - notificações via Telegram

# - notificações no celular

# ============================================================

# V5 — COLETA DE NOTÍCIAS FINANCEIRAS

# ============================================================

#

# Objetivo:

# Coletar automaticamente notícias relacionadas ao mercado.

#

# Técnicas utilizadas:

#

# Web Scraping

#

# Possíveis fontes:

#

# - portais financeiros

# - notícias econômicas

# - comunicados de empresas

#

# As notícias serão armazenadas em banco de dados

# para análises futuras.

# ============================================================

# V6 — ANÁLISE DE SENTIMENTO

# ============================================================

#

# Objetivo:

# Usar inteligência artificial para classificar notícias.

#

# Classificação:

#

# POSITIVA

# NEUTRA

# NEGATIVA

#

# Exemplo:

#

# "Empresa anuncia aumento de lucro"

# → sentimento positivo

#

# "Empresa anuncia prejuízo"

# → sentimento negativo

#

# Isso permite avaliar impacto de notícias

# sobre o mercado.

# ============================================================

# V7 — SISTEMA DE SCORE DAS AÇÕES

# ============================================================

#

# Objetivo:

# Criar um score quantitativo para cada ação.

#

# O score combina:

#

# - indicadores técnicos

# - notícias

# - histórico de preços

# - volatilidade

#

# Exemplo de escala:

#

# -100 → extremamente negativo

# 0 → neutro

# +100 → extremamente positivo

#

# Exemplo:

#

# PETR4 → score 72

# VALE3 → score 55

# ITUB4 → score 81

#

# Isso gera um ranking inteligente

# de oportunidades de investimento.

# ============================================================

# V7.5 — OTIMIZAÇÃO DE PORTFÓLIO

# ============================================================

#

# Objetivo:

# Construir portfólios ideais de investimento.

#

# Baseado na teoria moderna de portfólio.

#

# Ideia central:

#

# maximizar retorno

# minimizar risco

#

# usando:

#

# - retornos esperados

# - volatilidade

# - correlação entre ativos

# ============================================================

# V8 — BACKTESTING

# ============================================================

#

# Objetivo:

# Testar estratégias utilizando dados históricos.

#

# Exemplo:

#

# Estratégia:

#

# comprar ações com score > 70

#

# O sistema simula:

#

# - compras

# - vendas

# - retorno acumulado

#

# Isso permite medir:

#

# - retorno da estratégia

# - risco

# - precisão do modelo

# ============================================================

# V9 — INTERFACE GRÁFICA

# ============================================================

#

# Objetivo:

# Criar um dashboard visual do mercado.

#

# Funcionalidades:

#

# - lista de ações

# - gráficos interativos

# - indicadores técnicos

# - scores

# - rankings

# - alertas

#

# O usuário poderá clicar em uma ação

# e visualizar todas as informações

# em uma interface visual.

# ============================================================

# ============================================================

# BIBLIOTECAS PRINCIPAIS DO PROJETO

# ============================================================

# Manipulação de dados

#import pandas as pd
#import numpy as np

# Coleta de dados de mercado

#import yfinance as yf

# Visualização de gráficos

#import matplotlib.pyplot as plt
#import seaborn as sns
#import plotly.express as px

# Indicadores técnicos

#import ta

# Manipulação de datas

#import datetime as dt

# Web scraping

#import requests
#from bs4 import BeautifulSoup

# Processamento de texto (NLP)

#import nltk
#from textblob import TextBlob

# Machine Learning

#from sklearn.model_selection import train_test_split
#from sklearn.ensemble import RandomForestClassifier

# Banco de dados

#import sqlite3

# Sistema operacional

#import os

# Estatística

#from scipy import stats

# Avisos

#import warnings
#warnings.filterwarnings("ignore")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import yfinance as yf
import time
acoes = ["PETR4","VALE3","ITUB4","BBDC4","BBAS3","WEGE3","LREN3","MGLU3","RAIL3","ABEV3"]
for a in acoes:
    time.sleep(1)
    dados = yf.download(f"{a}.SA", start="2020-01-01")
    
    dados.reset_index(inplace=True)
    dados.to_csv(f"../dados/dados_brutos_{a}.csv",index=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf

print(yf.download("PETR4.SA", period="1y"))
print(yf.download("JBSS3.SA", period="1y"))
print(yf.download("ELET3.SA", period="1y"))

# %%
# ==========================================
# BOT DE ANÁLISE DE AÇÕES
# Projeto pessoal de aprendizado em:
# - Python
# - Mercado financeiro
# - Análise de dados
#
# VISÃO DO PROJETO:
# Criar um bot que analise ações, notícias e dados históricos
# para ajudar na tomada de decisão de investimentos.
#
# ------------------------------------------
# VERSÃO 1 (ATUAL)
# - Baixar dados de ações brasileiras
# - Mostrar preço atual
# - Mostrar variação
# - Plotar gráfico histórico
#
# ------------------------------------------
# FUTURAS VERSÕES
#
# V2
# - Analisar várias ações automaticamente
# - Criar ranking simples de desempenho
#
# V3
# - Adicionar indicadores técnicos
#   - média móvel
#   - volume
#   - volatilidade
#   
#
# V4
#   
#   - Sistema de alertas
#   - ações que subiram muito
#   - ações que caíram muito

#
# V5
# - Scraping de notícias financeiras
# - Banco de dados de notícias
#
# V6
# - IA para analisar notícias
# - Classificar sentimento da notícia
#   (positivo / neutro / negativo)
#
# V7
# - Score de investimento (-1000 até 1000)
# baseado em:
#   - notícias
#   - histórico
#   - indicadores
#   
# V8
# - backtesting para testar estratégias de investimento e ver precisão do bot
# V9
# - Interface gráfica (GUI)  (Clicar na ação e ver detalhes (gráficos, notícias, score ...))
# - Dashboard completo do mercado
#
# ==========================================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %%
import yfinance as yf
import pandas as pd

acoes = ["PETR4.SA","VALE3.SA","ITUB4.SA","BBDC4.SA","BBAS3.SA","WEGE3.SA","LREN3.SA","JBSS3.SA","RAIL3.SA","ELET3.SA"]

for a in acoes:

    dados = yf.download(f"{a}.SA", start="2020-01-01")
    dados.reset_index(inplace=True)
    nome = a.replace(".SA","")

    dados.to_csv(f"C:\\Users\\Bruno\\Desktop\\programacao\\Projetos\\bot_invest\\dados\\dados_brutos_{nome}.csv",index=False)

    print(f"Dados de {nome} atualizados!")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

hoje = pd.Timestamp.today()
print (hoje)
ticket = "PETR4.SA"
soma = 0
dados = pd.read_csv("C:\\Users\\Bruno\\Desktop\\programacao\\Projetos\\bot_invest\\dados\\dados_brutos_PETR4.csv", header=1)
dados.head()

# %%
dados = pd.read_csv("C:\\Users\\Bruno\\Desktop\\programacao\\Projetos\\bot_invest\\dados\\dados_brutos_PETR4.csv", header=2)
x = 0
y = 0
preco_medio_atual = 0
for linha in dados.index:
    x = dados.iloc[linha, 0]
    y = (dados.iloc[linha, 2] + dados.iloc[linha, 3])/2
    if linha == dados.index[-1]:
        preco_medio_atual = y
    plt.scatter(x, y)
print(preco_medio_atual)
plt.xlabel("Tempo")
plt.ylabel("Média do Preço")
plt.title("Análise de Dados do Ticket PETR4.SA")
plt.show()

# %%
acoes = ["PETR4","VALE3","ITUB4"]
cores = ['red', 'blue', 'green']
for a in acoes:
    dados = pd.read_csv(f"C:\\Users\\Bruno\\Desktop\\programacao\\Projetos\\bot_invest\\dados\\dados_brutos_{a}.csv", header=2)
    xs = []
    ys = []
    preco_medio_atual = 0
    for linha in dados.index:
        x = linha
        y = (dados.iloc[linha, 2] + dados.iloc[linha, 3])/2
        xs.append(x)
        ys.append(y)
        if linha == dados.index[-1]:
            preco_medio_atual = "{:.2f}".format(y)
    if a == "PETR4":
        cor = 'red'
    elif a == "VALE3":
        cor = 'blue'
    else:
        cor = 'green'
    plt.plot(xs, ys,color=cor)
    print(f"Preço Médio atual da Ação {a} = {preco_medio_atual}R$")
    plt.xlabel("Tempo (Dias)")
    plt.ylabel("Média do Preço")
    plt.title(f"Análise de Dados da Ação {a}.SA")
    plt.show()

# %%
acoes = ["PETR4","VALE3","ITUB4"]
cor = ['red', 'blue', 'green']
for a in acoes:
    dados = pd.read_csv(f"C:\\Users\\Bruno\\Desktop\\programacao\\Projetos\\bot_invest\\dados\\dados_brutos_{a}.csv", header=2)
    xs = []
    ys = []
    preco_medio_atual = 0
    for linha in dados.index:
        x = linha
        y = (dados.iloc[linha, 2] + dados.iloc[linha, 3])/2
        xs.append(x)
        ys.append(y)
        if linha == dados.index[-1]:
            preco_medio_atual = "{:.2f}".format(y)
    if a == "PETR4":
        plt.plot(xs, ys , color='red')
    elif a == "VALE3":
        plt.plot(xs, ys , color='blue')
    else:
        plt.plot(xs, ys , color='green')
    print(f"Preço Médio atual da Ação {a} = {preco_medio_atual}R$")
plt.xlabel("Tempo (Dias)")
plt.ylabel("Média do Preço")
plt.title("Análise de Dados das Ações.SA")
plt.legend(acoes)    
plt.show()

# %%
acoes = ["PETR4","VALE3","ITUB4"]
cor = ['red', 'blue', 'green']
for a in acoes:
    dados = pd.read_csv(f"C:\\Users\\Bruno\\Desktop\\programacao\\Projetos\\bot_invest\\dados\\dados_brutos_{a}.csv", header=2)
    xs = []
    ys = []
    for linha in dados.index:
        x = linha
        y = dados.iloc[linha, 1]
        xs.append(x)
        ys.append(y)
    if a == "PETR4":
        plt.plot(xs, ys , color='red')
    elif a == "VALE3":
        plt.plot(xs, ys , color='blue')
    else:
        plt.plot(xs, ys , color='green')
    print(f"Preço Médio atual da Ação {a} = {dados.iloc[-1, 1]:.2f}R$")
plt.xlabel("Tempo (Dias)")
plt.ylabel("Média do Preço")
plt.title("Análise de Dados das Ações.SA")
plt.legend(acoes)    
plt.show()

# %%
acoes = ["PETR4","VALE3","ITUB4"]
cor = ['red', 'blue', 'green']
for a in acoes:
    dados = pd.read_csv(f"C:\\Users\\Bruno\\Desktop\\programacao\\Projetos\\bot_invest\\dados\\dados_brutos_{a}.csv", header=2)
    dados.columns[0] = pd.to_datetime(dados.columns[0])
    xs = []
    ys = []
    for linha in dados.index:
        x = linha
        y = dados.iloc[linha, 1]
        xs.append(x)
        ys.append(y)
    if a == "PETR4":
        plt.plot(xs, ys , color='red')
    elif a == "VALE3":
        plt.plot(xs, ys , color='blue')
    else:
        plt.plot(xs, ys , color='green')
    print(f"Preço Médio atual da Ação {a} = {dados.iloc[-1, 1]:.2f}R$")
plt.xlabel("Tempo (Dias)")
plt.ylabel("Média do Preço")
plt.title("Análise de Dados das Ações.SA")
plt.legend(acoes)    
plt.show()

# %%
acoes = ["PETR4","VALE3","ITUB4"]
cor = ['red', 'blue', 'green']
for a in acoes:
    dados = pd.read_csv(f"C:\\Users\\Bruno\\Desktop\\programacao\\Projetos\\bot_invest\\dados\\dados_brutos_{a}.csv", header=1)
    xs = pd.to_datetime(dados["Date"])
    ys = dados["Close"]
    if a == "PETR4":
        plt.plot(xs, ys , color='red')
    elif a == "VALE3":
        plt.plot(xs, ys , color='blue')
    else:
        plt.plot(xs, ys , color='green')
    print(f"Preço Médio atual da Ação {a} = {dados.iloc[-1, 1]:.2f}R$")
plt.xlabel("Tempo")
plt.ylabel("Média do Preço")
plt.title("Análise de Dados das Ações.SA")
plt.legend(acoes)    
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import yfinance as yf
verde = "\033[92m"
vermelho = "\033[91m"
reset = "\033[0m"
acoes = ["PETR4","VALE3","ITUB4"]
dados = pd.read_csv(f"C:\\Users\\Bruno\\Desktop\\programacao\\Projetos\\bot_invest\\dados\\dados_brutos_PETR4.csv", header=1)


for a in acoes:
    dados = yf.download(f"{a}.SA", start="2020-01-01")
    dados.reset_index(inplace=True)
    nome = a.replace(".SA","")
    dados.to_csv(f"C:\\Users\\Bruno\\Desktop\\programacao\\Projetos\\bot_invest\\dados\\dados_brutos_{nome}.csv",index=False)
for a in acoes:
    dados = pd.read_csv(f"C:\\Users\\Bruno\\Desktop\\programacao\\Projetos\\bot_invest\\dados\\dados_brutos_{a}.csv", header=1)

    xs = pd.to_datetime(dados.iloc[:, 0])
    ys = dados.iloc[:, 1]

    if a == "PETR4":
        plt.plot(xs, ys , color='red')
    elif a == "VALE3":
        plt.plot(xs, ys , color='blue')
    else:
        plt.plot(xs, ys , color='green')
    k = dados.iloc[-1, 1] - dados.iloc[-2, 1]
    variacao = (k * 100)/dados.iloc[-2, 1]
    if variacao > 0:
        print(f"Preço Médio atual da Ação{verde} {a} = {dados.iloc[-1, 1]:.2f}R$ Subiu +{variacao:.2f}%{reset}")
    else:
        print(f"Preço Médio atual da Ação{vermelho} {a} = {dados.iloc[-1, 1]:.2f}R$ Caiu  {variacao:.2f}%{reset}")

plt.xlabel("Tempo")
plt.ylabel("Média do Preço")
plt.title("Análise de Dados das Ações.SA")
plt.legend(acoes)

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.xaxis.set_minor_locator(mdates.MonthLocator())

plt.grid()
plt.show()

# %%
# - Criar Modos de Visualização: 
#   1 — Ranking de ações OK
#   2 — Análise de uma ação OK
#   3 — Backtest
#   4 — Portfólio do usuário
#   5 — Alertas
#   6 — Notícias
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import yfinance as yf
from tabulate import tabulate
dados_path = Path("../dados")

dados_acoes = {}

for arquivo in dados_path.glob("dados_brutos_*.csv"):
    
    nome_acao = arquivo.stem.replace("dados_brutos_", "")
    
    dado = pd.read_csv(arquivo, header=1)
    
    dados_acoes[nome_acao] = dado


verde = "\033[92m"
vermelho = "\033[91m"
reset = "\033[0m"
acoes = ["PETR4","VALE3","ITUB4","BBDC4","BBAS3","WEGE3","LREN3","MGLU3","RAIL3","ABEV3"]
z = 0
b = 0
for a in acoes:

    dados_old = dados_acoes[a]

    ultima_data = pd.to_datetime(dados_old.iloc[-1, 0]).normalize()
    hoje = pd.Timestamp.today().normalize()

    if ultima_data != hoje:

        novos = yf.download(f"{a}.SA", start=ultima_data + pd.Timedelta(days=1))

        if novos.empty:
            continue

        if isinstance(novos.columns, pd.MultiIndex):
            novos.columns = novos.columns.droplevel(1)

        novos.reset_index(inplace=True)

        novos.iloc[:, 0] = pd.to_datetime(novos.iloc[:, 0], errors="coerce")

        novos = novos.dropna(subset=[novos.columns[0]])

        if ultima_data != novos.iloc[-1, 0].normalize():

            novos = novos.loc[:, ~novos.columns.duplicated()]
            dados_old = dados_old.loc[:, ~dados_old.columns.duplicated()]

            colunas_comuns = dados_old.columns.intersection(novos.columns)
            novos = novos[colunas_comuns]
            dados_old = dados_old[colunas_comuns]

            dados = pd.concat([dados_old, novos], ignore_index=True)

            dados = dados.drop_duplicates(subset=[dados.columns[0]])

            dados.to_csv(dados_path / f"dados_brutos_{a}.csv", index=False)

            dados_acoes[a] = dados

            print(f"{a} atualizado")

PETR4 = dados_acoes["PETR4"]
VALE3 = dados_acoes["VALE3"]
ITUB4 = dados_acoes["ITUB4"]
BBDC4 = dados_acoes["BBDC4"]
BBAS3 = dados_acoes["BBAS3"]
WEGE3 = dados_acoes["WEGE3"]
LREN3 = dados_acoes["LREN3"]
RAIL3 = dados_acoes["RAIL3"]
MGLU3 = dados_acoes["MGLU3"]
ABEV3 = dados_acoes["ABEV3"]
soma3 = 0

def c_p(valor):
    if valor > 0:
        return f"\033[92m+{valor:.2f}%\033[0m"
    elif valor < 0:
        return f"\033[91m{valor:.2f}%\033[0m"
    else:
        return f"{valor:.2f}%"

acoes_dados = [PETR4, VALE3, ITUB4, BBDC4, BBAS3, WEGE3, LREN3, MGLU3, RAIL3, ABEV3]
retornos_1m = []
retornos_6m = []
retornos_12m = []
volatilidades = []
momentums = []
scores = []
for dados in acoes_dados:
    r1 = ((dados.iloc[-1, 1] - dados.iloc[-21, 1]) / dados.iloc[-21, 1])
    r6 = ((dados.iloc[-1, 1] - dados.iloc[-126, 1]) / dados.iloc[-126, 1])
    r12 = ((dados.iloc[-1, 1] - dados.iloc[-252, 1]) / dados.iloc[-252, 1])
    v = dados.iloc[:, 1].pct_change().tail(252).std() * (252 ** 0.5)
    m = r12 - r1
    s = 0.35 * m + 0.30 * r6 + 0.25 * r12 - 0.10 * v
    retornos_1m.append(r1)
    retornos_6m.append(r6)
    retornos_12m.append(r12)
    volatilidades.append(v)
    momentums.append(m)
    scores.append(s)
d = {
"Ação": acoes,
"Retorno 1M": [f"{r*100:+.2f}%" for r in retornos_1m],
"Retorno 6M": [f"{r*100:+.2f}%" for r in retornos_6m],
"Retorno 12M": [f"{r*100:+.2f}%" for r in retornos_12m],
"Volatilidade": [f"{v*100:+.2f}%" for v in volatilidades],
"Momentum": [f"{m*100:+.2f}%" for m in momentums],
"Score": scores
}
df = pd.DataFrame(d)
df["Score"] = df["Score"].round(2)
ranking = df.sort_values(by="Score", ascending=False).reset_index(drop=True)



while z == 0:
    inicio = input("Digite o número do modo de visualização:\n"
    "1 — Ranking de ações\n"
    "2 — Análise de uma ação\n"
    "3 — Backtest\n"
    "4 — Portfólio do usuário\n"
    "5 — Alertas\n"
    "6 — Notícias\n"
    "0 - Sair\n")
    retornos_1m = []
    retornos_6m = []
    retornos_12m = []
    volatilidades = []
    momentums = []
    scores = []
    pms = []
    vars_ = []

    if inicio == "1":
        print("Ranking de ações")

        for dados in acoes_dados:
            va = ((dados.iloc[-1, 1] - dados.iloc[-2, 1])/ dados.iloc[-2, 1])
            pm = (dados.iloc[-1, 1])
            r1 = ((dados.iloc[-1, 1] - dados.iloc[-21, 1]) / dados.iloc[-21, 1])
            r6 = ((dados.iloc[-1, 1] - dados.iloc[-126, 1]) / dados.iloc[-126, 1])
            r12 = ((dados.iloc[-1, 1] - dados.iloc[-252, 1]) / dados.iloc[-252, 1])
            v = dados.iloc[:, 1].pct_change().tail(252).std() * (252 ** 0.5)
            m = r12 - r1
            s = 0.35 * m + 0.30 * r6 + 0.25 * r12 - 0.10 * v
            retornos_1m.append(r1)
            retornos_6m.append(r6)
            retornos_12m.append(r12)
            volatilidades.append(v)
            momentums.append(m)
            scores.append(s)
            pms.append(pm)
            vars_.append(va)
        d = {
        "Ação": acoes,
        "Preço Médio Atual": [f"{p:.2f}" for p in pms],
        "Variação Diária": [c_p(v*100)for v in vars_],
        "Retorno 1M": [c_p(r*100) for r in retornos_1m],
        "Retorno 6M": [c_p(r*100) for r in retornos_6m],
        "Retorno 12M": [c_p(r*100) for r in retornos_12m],
        "Volatilidade": [c_p(v*100) for v in volatilidades],
        "Momentum": [c_p(m*100) for m in momentums],
        "Score": scores
        }
        df = pd.DataFrame(d)
        df["Score"] = df["Score"].round(2)
        ranking = df.sort_values(by="Score", ascending=False).reset_index()
        top10 = ranking.head(10)
        choice = input("1 - Ranking Completo\n2 - Top 10\n")

        if choice == "1":
            print(tabulate(ranking, headers="keys", tablefmt="fancy_grid", numalign="center", stralign="center"))
            l = int(input("Gostaria de retornar ao menu? (1 - Sim, 0 - Sair)"))
            if l == 1:
                z = 0
            else:
                z = 1
        elif choice == "2":
            print(tabulate(top10, headers="keys", tablefmt="fancy_grid", numalign="center", stralign="center"))
            l = int(input("Gostaria de retornar ao menu? (1 - Sim, 0 - Sair)"))
            if l == 1:
                z = 0
            else:
                z = 1
        else:
            print("Opção inválida")
            z = 0
    elif inicio == "2":
        while True:
            print("Análise de uma ação")
            anal = input("Digite o nome da ação que deseja analisar (PETR4, VALE3, ITUB4, etc): ")
            if anal in acoes:
                print(f"Analisando a ação {anal}.SA")
                dados = pd.read_csv(dados_path / f"dados_brutos_{anal}.csv", header=1)
                preco = dados.iloc[-1, 1]
                r1 = ((dados.iloc[-1, 1] - dados.iloc[-21, 1]) / dados.iloc[-21, 1])
                r6 = ((dados.iloc[-1, 1] - dados.iloc[-126, 1]) / dados.iloc[-126, 1])
                r12 = ((dados.iloc[-1, 1] - dados.iloc[-252, 1]) / dados.iloc[-252, 1])
                v = dados.iloc[:, 1].pct_change().tail(252).std() * (252 ** 0.5)
                m = r12 - r1
                va = ((dados.iloc[-1, 1] - dados.iloc[-2, 1])/ dados.iloc[-2, 1])
                s = 0.35 * m + 0.30 * r6 + 0.25 * r12 - 0.10 * v
                print("" \
                f"""
    ==================================================
                {f"ANÁLISE DA AÇÃO — {anal}.SA":^26}
    ==================================================

    {f"Preço Médio Atual:":<30}{preco:.2f}R$
    {f"Variação Diária:":<30}{c_p(va * 100)}
    {f"Retorno 1M:":<30}{c_p(r1 * 100)}
    {f"Retorno 6M:":<30}{c_p(r6 * 100)}
    {f"Retorno 12M:":<30}{c_p(r12 * 100)}

    ---------------- RETORNOS ----------------

    {f"Volatilidade:":<30}{c_p(v*100)}
    {f"Momentum:":<30}{c_p(m*100)}
    {f"Score:":<30}{s:.2f}
    {f"Ranking:":<30}{ranking[ranking['Ação'] == anal].index[0] + 1}° lugar

    ---------------- ALERTAS ----------------



    ---------------- NOTÍCIAS ----------------



    ---------------- MODELO ----------------






    """) 






                xs = pd.to_datetime(dados.iloc[:, 0])
                ys = dados.iloc[:, 1]
                plt.plot(xs, ys , color='blue')
                plt.xlabel("Tempo")
                plt.ylabel("Média do Preço")
                plt.title(f"Análise de Dados da Ação {anal}.SA")
                plt.show()
                k = int(input("Gostaria de analisar outra ação? (1 - Sim, 2 - Menu, 0 - Sair)"))
                if k == 1:
                    pass
                elif k == 0:
                    z = 1
                    break
                elif k == 2:
                    break
                else:
                    print("Opção inválida")
                    k = 0
            else:
                print("Ainda não temos dados dessa ação")
                k = int(input("Gostaria de tentar outra ação? (1 - Sim, 2 - Menu, 0 - Sair)"))
                if k == 1:
                    pass
                elif k == 0:
                    z = 1
                    break
                elif k == 2:
                    break
                else:
                    print("Opção inválida")
                    
    elif inicio == "3":
        print("Backtest")
    elif inicio == "4":
        print("Portfólio do usuário")
        ind = []
        qnt = []
        actions = []
        retornos_1m = []
        retornos_6m = []
        retornos_12m = []
        volatilidades = []
        momentums = []
        scores = []
        pms = []
        vars_ = []
        valor_at =[]
        volc = 0
        valor_tot = float(input("Quanto você gastou no seu portifólio: "))
        while True:

            ac = input("Digite sua ação (PETR4, VALE3, ITUB4, etc.):\n"
            "1 - Mostrar Portifólio\n"
            "0 - Sair ")
            if ac == "0":
                break

            elif ac == "1":
                xa = 0
                rae = 0
                volc = 0
                for i in ind:
                    va = ((acoes_dados[ind.index(i)].iloc[-1, 1] - acoes_dados[ind.index(i)].iloc[-2, 1])/ acoes_dados[ind.index(i)].iloc[-2, 1])
                    pm = (acoes_dados[ind.index(i)].iloc[-1, 1])
                    r1 = ((acoes_dados[ind.index(i)].iloc[-1, 1] - acoes_dados[ind.index(i)].iloc[-21, 1]) / acoes_dados[ind.index(i)].iloc[-21, 1])
                    r6 = ((acoes_dados[ind.index(i)].iloc[-1, 1] - acoes_dados[ind.index(i)].iloc[-126, 1]) / acoes_dados[ind.index(i)].iloc[-126, 1])
                    r12 = ((acoes_dados[ind.index(i)].iloc[-1, 1] - acoes_dados[ind.index(i)].iloc[-252, 1]) / acoes_dados[ind.index(i)].iloc[-252, 1])
                    v = acoes_dados[ind.index(i)].iloc[:, 1].pct_change().tail(252).std() * (252 ** 0.5)
                    m = r12 - r1
                    s = 0.35 * m + 0.30 * r6 + 0.25 * r12 - 0.10 * v
                    val_at = (acoes_dados[ind.index(i)].iloc[-1, 1] * (qnt[ind.index(i)]))
                    retornos_1m.append(r1)
                    retornos_6m.append(r6)
                    retornos_12m.append(r12)
                    volatilidades.append(v)
                    momentums.append(m)
                    scores.append(s)
                    pms.append(pm)
                    vars_.append(va)
                    actions.append(acoes[i])
                    valor_at.append(val_at)
                    soma3 = soma3 + val_at
                pla = {
                "Ação": actions,
                "Preço Médio Atual": [f"{pm:.2f}" for pm in pms],
                "Variação Diária": [c_p(va * 100)for va in vars_],
                "Retorno 1M": [c_p(r * 100) for r in retornos_1m],
                "Retorno 6M": [c_p(r * 100) for r in retornos_6m],
                "Retorno 12M": [c_p(r * 100) for r in retornos_12m],
                "Volatilidade": [c_p(v * 100) for v in volatilidades],
                "Momentum": [c_p(m * 100) for m in momentums],
                "Score": scores 
                }
                df2 = pd.DataFrame(pla)
                df2["Score"] = df2["Score"].round(2)
                pla1 = {
                "Ação": actions,
                "Quantidade": [q for q in qnt],
                "Preço Médio Atual": [f"{pm:.2f}" for pm in pms],
                "Valor Total": [v for v in valor_at],
                "Peso": [f"{(v / soma3)* 100 :.2f}%" for v in valor_at],
                "Score": scores
                }
                df3 = pd.DataFrame(pla1)
                df3["Score"] = df3["Score"].round(2)
                for a in actions:
                   rae = rae + pla["Retorno 12M"].iloc[xa] * pla1["Peso"].iloc[xa]
                   xa = xa + 1

                print("" \
                f"""
    ==================================================
                {f"Seu Portifólio":^26}
    ==================================================

    {f"Valor total gasto:":<30}{valor_tot:.2f}R$
    {f"Valor Das Ações:":<30}{soma3:.2f}R$
    {f"Lucro:":<30}{soma3 - valor_tot:.2f}R$ ou {((soma3 - valor_tot)/valor_tot)*100:.2f}%
    {f"Número de ativos:":<30}{len(actions)}
                

                
    ---------------- Ativos ----------------
    """
    )
                

                print(tabulate(df3, headers="keys", tablefmt="github", numalign="center", stralign="center"))

                
                print(f"""
    ---------------- Métricas Gerais ----------------

    Retorno anual esperado:  {rae}
    Volatilidade: "          {volc}%
    Sharpe Ratio: "          [em desenvolvimento]
    Drawdown máximo: "       [em desenvolvimento]





    ---------------- Análise Automática ----------------

    [em desenvolvimento]

    O sistema irá analisar:
    - concentração da carteira
    - risco do portfólio
    - qualidade dos ativos
    - diversificação

    Retornando Recomendações 




    """)
                break
            elif ac in acoes:
                ind.append(acoes.index(ac))
            else:
                print("Não Possuimos essa ação")
                pass
            qnt.append(int(input(f"Digite a quantidade de ações {ac} que você possui \n")))

        
                
    elif inicio == "5":
        print("Alertas")
    elif inicio == "6":
        print("Notícias")
    elif inicio == "0":
        print("Encerrando o programa...")
        z = 1
    else:
        print("Opção inválida")
        z = 0
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Ranking de ações
# ╒════╤═════════╤════════╤═════════════════════╤═══════════════════╤══════════════╤══════════════╤═══════════════╤════════════════╤════════════╤═════════╕
# ...

# %%
    {f"Volatilidade:":<30}{c_p(v*100)}
    {f"Momentum:":<30}{c_p(m*100)}
    {f"Score:":<30}{s:.2f}
    {f"Ranking:":<30}{ranking[ranking['Ação'] == anal].index[0] + 1}° lugar
    {f"Retorno 12M:"}{c_p(r12 * 100)}

# %%
from pathlib import Path

print(Path().resolve())
